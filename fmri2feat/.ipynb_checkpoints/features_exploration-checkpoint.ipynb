# %%
import numpy as np

# %%
data = np.load('../data/features/BOLD5000/resnet_feat.npy',allow_pickle=True)

# %%
data_dict = dict(enumerate(data.flatten(), 1))[1]

# %%
data_dict.keys()
# Out:
# dict_keys(['n03721384_567', 'COCO_train2014_000000054001', 'cabin4', 'n07742313_20683', 'n02268853_504', 'COCO_train2014_000000474024', 'n03445924_6637', 'COCO_train2014_000000282957', 'lake2', 'n02111277_2742', 'n01630670_321', 'n02130308_9559', 'n02892201_16519', 'COCO_train2014_000000425269', 'n02007558_11877', 'COCO_train2014_000000244646', 'closet5', 'COCO_train2014_000000181837', 'COCO_train2014_000000311796', 'n04033995_15656', 'COCO_train2014_000000510334', 'COCO_train2014_000000532520', 'COCO_train2014_000000275663', 'COCO_train2014_000000329919', 'n03871628_11370', 'deck2', 'COCO_train2014_000000304440', 'n02843684_21806', 'n02165456_9825', 'n03814906_39850', 'COCO_train2014_000000237663', 'COCO_train2014_000000517251', 'n01910747_1419', 'COCO_train2014_000000557886', 'COCO_train2014_000000120655', 'n02804414_6552', 'basement8', 'n07716358_26835', 'fireEscape7', 'COCO_train2014_000000523236', 'COCO_train2014_000000123891', 'n04550184_24353', 'n01669191_12735', 'n02979186_24
# ...

# %%
data_dict["COCO_train2014_000000296474"].keys()
# Out:
# dict_keys(['block1', 'block2', 'block3', 'block4', 'fc'])

# %%
print(len(data_dict["COCO_train2014_000000296474"]['fc']))
# Out:
# 1000

# %%
data_dict["COCO_train2014_000000296474"]['fc']
# Out:
# array([-1.93319726e+00, -1.97905838e+00,  2.13612604e+00,  6.55932426e-02,
#         8.19532096e-01, -1.74479043e+00, -3.73385549e+00,  1.19919109e+00,
#        -2.03743601e+00, -1.40321934e+00, -1.36634684e+00, -3.21180320e+00,
#        -8.14835191e-01, -1.14640689e+00, -2.97008634e+00, -3.33147550e+00,
#        -1.93664348e+00, -2.42718387e+00, -1.74436200e+00, -1.30698395e+00,
#        -2.21681476e+00, -1.04723823e+00, -7.44544268e-01,  8.70267868e-01,
#        -1.46161592e+00, -3.45271778e+00, -3.37528849e+00, -3.96978116e+00,
#        -1.46600485e+00, -4.74277210e+00, -3.24298596e+00, -5.16717958e+00,
#        -4.78180504e+00, -1.80370820e+00, -1.88775432e+00, -5.10085821e+00,
#        -2.46935773e+00, -3.71454215e+00, -2.01744437e+00, -1.73858666e+00,
#        -2.84552097e+00, -1.75950551e+00, -3.62859702e+00, -3.96569014e+00,
#        -2.11008668e+00, -1.88883185e+00, -3.20698357e+00, -4.25580645e+00,
# ...
