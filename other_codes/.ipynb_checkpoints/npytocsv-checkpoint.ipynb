# %%
import numpy as np

# %%
data = np.load('./results/vision_resnet.npy',allow_pickle=True)

# %%
d = dict(enumerate(data.flatten(), 1))

# %%
key = list(d[1].keys())

# %%
key
# Out:
# ['2v2', 'pear', 'rdm_feats', 'rdm_voxels']

# %%
d[1]['pear']
# Out:
# {'P01': [0.853, 0.858, 0.872, 0.785, 0.664],
#  'M01': [0.781, 0.783, 0.794, 0.668, 0.522],
#  'M02': [0.769, 0.77, 0.781, 0.629, 0.475],
#  'M03': [0.769, 0.772, 0.781, 0.648, 0.508],
#  'M04': [0.801, 0.804, 0.817, 0.683, 0.56],
#  'M05': [0.882, 0.888, 0.904, 0.834, 0.715],
#  'M06': [0.742, 0.743, 0.75, 0.591, 0.452],
#  'M07': [0.842, 0.846, 0.861, 0.75, 0.585],
#  'M08': [0.633, 0.636, 0.646, 0.444, 0.321],
#  'M09': [0.826, 0.828, 0.839, 0.721, 0.587],
#  'M10': [0.839, 0.843, 0.854, 0.749, 0.61],
#  'M13': [0.742, 0.745, 0.757, 0.59, 0.441],
#  'M14': [0.806, 0.809, 0.82, 0.68, 0.539],
#  'M15': [0.775, 0.783, 0.808, 0.688, 0.545],
#  'M16': [0.736, 0.738, 0.755, 0.622, 0.489],
#  'M17': [0.705, 0.704, 0.713, 0.547, 0.391]}

# %%
subjects = list(d[1]['pear'].keys())

# %%
for k in key:
    data = d[1][k]
    print(k)
    for subj in subjects:
        for i in range(0,5):
            if(i < 4):
                print(data[subj][i],end = "\t")
            else:
                print(data[subj][i])
    
    print()
    print()
# Out:
# 2v2
# 0.83	0.865	0.926	0.84	0.81
# 0.733	0.768	0.823	0.736	0.678
# 0.735	0.743	0.823	0.636	0.552
# 0.683	0.706	0.762	0.646	0.584
# 0.758	0.781	0.848	0.702	0.669
# 0.838	0.881	0.944	0.886	0.789
# 0.69	0.706	0.764	0.648	0.612
# 0.786	0.821	0.901	0.742	0.657
# 0.684	0.701	0.76	0.585	0.562
# 0.772	0.795	0.899	0.743	0.658
# 0.74	0.791	0.865	0.722	0.66
# 0.743	0.777	0.841	0.695	0.654
# 0.716	0.749	0.841	0.626	0.551
# 0.801	0.844	0.925	0.823	0.737
# 0.73	0.759	0.828	0.743	0.684
# 0.709	0.693	0.806	0.683	0.578
#
#
# pear
# 0.853	0.858	0.872	0.785	0.664
# 0.781	0.783	0.794	0.668	0.522
# 0.769	0.77	0.781	0.629	0.475
# 0.769	0.772	0.781	0.648	0.508
# 0.801	0.804	0.817	0.683	0.56
# 0.882	0.888	0.904	0.834	0.715
# 0.742	0.743	0.75	0.591	0.452
# 0.842	0.846	0.861	0.75	0.585
# 0.633	0.636	0.646	0.444	0.321
# 0.826	0.828	0.839	0.721	0.587
# 0.839	0.843	0.854	0.749	0.61
# 0.742	0.745	0.757	0.59	0.441
# 0.806	0.809	0.82	0.68	0.539
# 0.775	0.783	0.808	0.688	0.545
# 0.736	0.738	0.755	0.622	0.489
# ...
